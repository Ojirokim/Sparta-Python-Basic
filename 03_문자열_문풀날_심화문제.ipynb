# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "id": "ae065611",
   "metadata": {},
   "source": [
    "# 02_변수_심화문제\n",
    "\n",
    "1) `strip()`을 했는데 원본이 안 바뀌는 이유는?  \n",
    "2) `s[0] = \"X\"`가 왜 안 되나요?  \n",
    "3) `s[0:2]`에서 2는 왜 포함되지 않나요?  \n",
    "4) `s[-1]`과 `s[-1:]`의 차이는 무엇인가요?  \n",
    "5) `find()`가 0을 반환하는 경우를 예시로 보여보세요.  \n",
    "6) `if s.find(\"a\"):` 가 왜 위험한 조건문인지 설명해 보세요.  \n",
    "7) `\"10, 20, 30\".split(\",\")` 결과에 공백이 남는 이유와 해결 방법은?  \n",
    "8) `\"a,b,c\"`를 `\"a|b|c\"`로 바꾸는 가장 쉬운 방법은?  \n",
    "9) 경로 문자열에서 `\\n` 문제가 생기는 예시와 raw 문자열로 해결하는 예시는?  \n",
    "10) (도전) 이메일에서 도메인만 뽑아서 대문자로 출력해 보세요.\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "70f303da",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문자열 종합 문제 1\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "ba9ae8a0",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문자열 종합 문제 2\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "553aa1dc",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문자열 종합 문제 3\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "76224c5e",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문자열 종합 문제 4\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "674bd8e5",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문자열 종합 문제 5\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "778956e4",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문자열 종합 문제 6\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "6283a79d",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문자열 종합 문제 7\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "1c9e1c04",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문자열 종합 문제 8\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "379f63b6",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문자열 종합 문제 9\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "0f4072f4",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문자열 종합 문제 10\n",
    "# TODO\n"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
