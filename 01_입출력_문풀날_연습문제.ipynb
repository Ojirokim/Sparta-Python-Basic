# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "id": "887b8d7e",
   "metadata": {},
   "source": [
    "### 🧩 연습문제: `print`, `sep`, `end` (총 8문제)\n",
    "\n",
    "**문제 1)** 아래 출력이 나오도록 `sep`를 사용해 보세요.  \n",
    "목표 출력: `a-b-c`\n",
    "\n",
    "**문제 2)** 아래 출력이 나오도록 `sep`를 사용해 보세요.  \n",
    "목표 출력: `2026/01/04` (01, 04처럼 0 포함은 아직 어렵다면 `2026/1/4`도 괜찮습니다)\n",
    "\n",
    "**문제 3)** 아래 출력이 한 줄로 이어지게 `end`를 사용해 보세요.  \n",
    "목표 출력: `Hello World`\n",
    "\n",
    "**문제 4)** 아래 출력이 나오도록 `sep`와 `end`를 같이 써 보세요.  \n",
    "목표 출력: `A|B|C...DONE`\n",
    "\n",
    "**문제 5)** 다음 코드를 수정해서 `1 2 3 4 5`가 한 줄로 나오게 해 보세요.\n",
    "\n",
    "**문제 6)** `print()`를 2번만 써서 다음처럼 출력해 보세요.  \n",
    "목표 출력:\n",
    "```\n",
    "사과 / 바나나 / 포도\n",
    "끝\n",
    "```\n",
    "\n",
    "**문제 7)** 문자열 `\"1\"`과 숫자 `1`을 각각 출력해 보고, 차이를 말해 보세요(직접 실행).\n",
    "\n",
    "**문제 8)** 아래와 같은 “진행바 느낌”을 만들어 보세요.  \n",
    "목표 출력(예시): `0...1...2...3...4...끝!`\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "68b142af",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 1\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "ae9d123a",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 1\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "6cfec77b",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 2\n",
    "# TODO\n",
    "money = 9876543\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "7b2f6c86",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 3\n",
    "# TODO\n",
    "avg = 3.14159\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "abf00410",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 4\n",
    "name = \"적토마\"\n",
    "print(\"{name}님 반갑습니다!\")  # TODO: 왜 그대로 나오나요? 어떻게 고치나요?\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "d6cd0fce",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 5\n",
    "# TODO\n",
    "a, b = 12, 5\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "948c6bca",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 6\n",
    "# TODO\n",
    "price = 12345.6\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "9510d971",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 7\n",
    "# TODO (format 사용)\n",
    "money = 9876543\n"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "677d5960",
   "metadata": {},
   "source": [
    "### 🧩 연습문제: f-string / format (총 7문제)\n",
    "\n",
    "**문제 1)** `name=\"적토마\"`, `age=15`일 때:  \n",
    "`적토마의 나이는 15살입니다.` 를 f-string으로 출력해 보세요.\n",
    "\n",
    "**문제 2)** `money=9876543`일 때:  \n",
    "`총액: 9,876,543원` 을 f-string으로 출력해 보세요.\n",
    "\n",
    "**문제 3)** `avg=3.14159`일 때:  \n",
    "`평균: 3.14` 를 f-string으로 출력해 보세요.\n",
    "\n",
    "**문제 4)** (헷갈림) 아래 코드에서 왜 `{name}`이 그대로 나오나요?  \n",
    "힌트: `f`를 확인하세요.\n",
    "\n",
    "**문제 5)** `a=12`, `b=5`일 때:  \n",
    "`12 / 5 = 2.40` 을 f-string으로 출력해 보세요(소수 둘째 자리).\n",
    "\n",
    "**문제 6)** `price=12345.6`일 때:  \n",
    "`가격: 12,345.60원` 을 f-string으로 출력해 보세요(콤마 + 소수 둘째 자리).\n",
    "\n",
    "**문제 7)** `format()`으로도 문제 2를 똑같이 출력해 보세요.\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "e0dc48d1",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 1\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "ffffa3c0",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 2\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "ed6277f8",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 3\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "43c8eb23",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 4\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "dc9d0f8e",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 5\n",
    "# TODO\n",
    "for i in range(1, 6):\n",
    "    print(i)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "6b271fd9",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 6\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "cf60845f",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 7\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "58b97cb4",
   "metadata": {},
   "source": [
    "### 🧩 연습문제: input + 형변환 + 예외처리 (총 9문제)\n",
    "\n",
    "**문제 1)** 사용자가 정수를 입력하면 2배를 출력하세요.  \n",
    "**문제 2)** 사용자가 실수를 입력하면 1을 더해서 출력하세요.  \n",
    "**문제 3)** (헷갈림) 사용자 입력 두 개를 받아 `a+b`를 출력할 때, 왜 `\"12\"`가 나오기도 하나요? 직접 실험해 보세요.  \n",
    "**문제 4)** 공백으로 구분된 정수 2개를 입력받아 `합/차/곱`을 출력하세요.  \n",
    "**문제 5)** 위 문제에서 입력이 이상하면 “형식이 잘못되었습니다”를 출력하세요. (`try/except`)  \n",
    "**문제 6)** `x,y` 형태(쉼표 구분)로 정수 2개를 입력받아 곱을 출력하세요.  \n",
    "**문제 7)** `1,000` 같은 입력도 받을 수 있게 콤마를 제거한 뒤 정수로 바꿔보세요.  \n",
    "**문제 8)** (헷갈림) `int(\"3.14\")`는 왜 실패하나요? 대신 어떤 변환을 써야 하나요? 직접 코드로 확인하세요.  \n",
    "**문제 9)** 0으로 나눌 때 프로그램이 멈추지 않게 처리하세요.\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "a75ad3c5",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 1\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "a2bd3aaf",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 2\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "b86d1db8",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 3\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "17999357",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 4\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "8ce97805",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 5\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "0a589a57",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 6\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "482904e4",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 7\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "5e29bf95",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 8\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "3a4050b8",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 문제 9\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "d003b3b4",
   "metadata": {},
   "source": [
    "### 🧩 연습문제: split + map (총 10문제)\n",
    "\n",
    "\n",
    "**문제 1)** 공백으로 구분된 정수 3개를 입력받아 합을 출력하세요.  \n",
    "**문제 2)** 쉼표로 구분된 정수 3개를 입력받아 평균을 출력하세요(소수 둘째 자리).  \n",
    "**문제 3)** `#`로 구분된 정수 4개를 입력받아 최댓값을 출력하세요.  \n",
    "**문제 4)** (헷갈림) `a, b = map(int, input().split())`에서 입력을 `10,20`으로 하면 왜 실패할까요? 해결하세요.  \n",
    "**문제 5)** `10, 20, 30`처럼 쉼표 뒤 공백이 있어도 잘 동작하도록 처리하세요.  \n",
    "**문제 6)** 입력이 정수가 아닐 경우 “정수만 입력하세요”라고 출력하세요.  \n",
    "**문제 7)** 입력이 2개가 아닐 경우 “정수 2개를 입력하세요”라고 출력하세요.  \n",
    "**문제 8)** 입력이 `1,000 2,000`처럼 콤마가 섞여 있어도 합이 나오게 해 보세요.  \n",
    "**문제 9)** 점수 3개를 입력받아 평균을 구하고, f-string으로 소수 둘째 자리까지 출력하세요.  \n",
    "**문제 10)** (도전) 입력 형식이 공백/쉼표/# 중 어떤 것이든 들어올 수 있습니다.  \n",
    "가능한 경우를 모두 지원해 보세요(힌트: 먼저 어떤 구분자가 있는지 검사).\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "e90a55b4",
   "metadata": {},
   "outputs": [],
   "source": [
    "# split/map 문제 1\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "5bdd8c54",
   "metadata": {},
   "outputs": [],
   "source": [
    "# split/map 문제 2\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "31703547",
   "metadata": {},
   "outputs": [],
   "source": [
    "# split/map 문제 3\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "7b60a053",
   "metadata": {},
   "outputs": [],
   "source": [
    "# split/map 문제 4\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "106816f3",
   "metadata": {},
   "outputs": [],
   "source": [
    "# split/map 문제 5\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "9a7a0354",
   "metadata": {},
   "outputs": [],
   "source": [
    "# split/map 문제 6\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "4ba78f8d",
   "metadata": {},
   "outputs": [],
   "source": [
    "# split/map 문제 7\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "a6bbb289",
   "metadata": {},
   "outputs": [],
   "source": [
    "# split/map 문제 8\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "a1d4f990",
   "metadata": {},
   "outputs": [],
   "source": [
    "# split/map 문제 9\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "5ee2296a",
   "metadata": {},
   "outputs": [],
   "source": [
    "# split/map 문제 10\n",
    "# TODO\n"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
