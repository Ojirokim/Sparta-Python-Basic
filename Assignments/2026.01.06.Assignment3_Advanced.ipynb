# %%
# 문자열 종합 문제 1

# %% [markdown]
# 원본에 직접 저장을 하지 않는 이상 변수는 불변한다.

# %%
# 문자열 종합 문제 2

# %% [markdown]
# 문자열은 기본 불변이기에, 문자열을 지정하여 수정하는 것은 불가능하기 때문이다.

# %%
# 문자열 종합 문제 3

# %% [markdown]
# 슬라이싱에 마지막 인덱스는 포함되지 않는다.

# %%
# 문자열 종합 문제 4

# %% [markdown]
# s[-1]는 마지막 문자열을 고르고, `s[-1:]`는 마지막 문자열부터 끝까지 고르는 의미이다.
# 둘다 str이지만, 하나는 인덱싱, 다른 하나는 슬라이싱이다.

# %%
# 문자열 종합 문제 5

# %%
x="1234"
x.find("1")
# Out:
# 0

# %%
# 문자열 종합 문제 6

# %% [markdown]
# find는 인덱스를 반환하는데, 첫번째 인덱스는0을 반환하기에 false를 의미하는 0과 같이 구별되어 버린다.

# %%
# 문자열 종합 문제 7

# %% [markdown]
# str이 나눠져있는 방식이 ","가 아니라", "이기 때문이다.

# %%
# 문자열 종합 문제 8

# %%
a= "a,b,c"
b= a.replace(",","|")
print(b)
# Out:
# a|b|c

# %%
# 문자열 종합 문제 9

# %%
path = "C:\new\test.txt"
print(path)
path = r"C:\new\test.txt"
print(path)

# %%
# 문자열 종합 문제 10

# %%
a= "magcojiro@gmail.com"
b= int(a.find("@"))
c= a[b+1:]
print(c)
# Out:
# gmail.com
