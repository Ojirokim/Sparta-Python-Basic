# %%
# 1
print("1", "2", sep="")
print("1" + "2")
# Out:
# 12
# 12

# %%
# 2
x=input()
print(type(x))
print(type(10))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# 3
# 천단위마다 ,를 넣어준다.
print(f"{1000:,}")
# Out:
# 1,000

# %%
# 4
int("1,000")
# int안에 들어가는 것이 float도 아니고, 숫자만으로 이루어진 string도 아니기 때문이다.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int("1,000")
#
# ValueError: invalid literal for int() with base 10: '1,000'

# %%
# 5
x= "10 20"
y=x.split(',')
print(y)
# Out:
# ['10 20']

# %% [markdown]
# 아무것도 split하지 않고 그대로 출력된다.

# %%
# 6
a, b = map(int, input().split())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 # 6
# ----> 2 a, b = map(int, input().split())
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# 오류는 받는 변수보다 넣는 변수의 개수가 많기 때문이다.

# %%
# 7
for x in range(1,11):
    print(x,end="")
    x = x+1
# Out:
# 12345678910

# %%
# 8
x= 12345
format(f'가격: {x:,}원')
# Out:
# '가격: 12,345원'

# %%
# 9

# %% [markdown]
# 입력 값을 정수인지 판단하는 경우에는 find를 사용하는 것은 비효율적이다. 오히려 try/except로 처리하는 것이 더 낫다.

# %%
# 10
x=input()
if x=='':
    print("아무것도 없슴네다")
# Out:
# 아무것도 없슴네다
