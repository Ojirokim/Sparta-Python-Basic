# %%
# TODO: 값은 자유롭게 바꿔도 됩니다.
allowance = 50000
snack = 12000
transport = 15000
game = 8000

# TODO 1: 총 지출 계산
total_spent = snack + transport + game
# TODO 2: 남은 돈 계산
remaining = allowance-total_spent
print(total_spent)
print(remaining)
