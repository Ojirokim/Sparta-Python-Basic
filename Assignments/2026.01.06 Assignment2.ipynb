# %%
# 연습문제 1-1
student_name ="학생"
print(student_name)
# Out:
# 학생

# %%
# 연습문제 1-2
single_price= 1200
print(single_price)
# Out:
# 1200

# %%
# 연습문제 1-3. 아래 코드를 수정하여 완성하세요.
wawa = 3
baba = 5
mama = wawa*baba
print(f"결과 : {mama}")
# Out:
# 결과 : 15

# %%
# 연습문제 1-4. 아래에 코드를 작성하세요.
Score=100
score=80
Score==score
# Out:
# False

# %%
# 연습문제 1-5. 아래에 코드를 작성하세요.
we='15'
WE=15
print(type(we))
print(type(WE))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# 연습문제 1-6. 아래에 코드를 작성하세요.
ER R= "WE"
## R부분이 ER에서 띄워져 있기에 오류가 발생한다.
## 해결하기 위해서는 ER_R사용해야함.
# Out:
#   Cell In[8], line 2
#     ER R= "WE"
#        ^
# SyntaxError: invalid syntax

# %%
# 연습문제 1-7. 아래에 코드를 작성하세요.
4D= 433
## 4부분에 문법적으로 숫자가 와서는 안된다.
## 해결하기 위해서는 ED로 바꿔야함.
# Out:
#   Cell In[9], line 2
#     4D= 433
#     ^
# SyntaxError: invalid decimal literal

# %%
# 1-8 연습문제 풀이를 아래 markdown 셀에 적어보세요.

# %% [markdown]
# 예약된 키워드는 고정된 의미를 가지고 있기 때문에 변수명으로 사용하지 못한다.

# %%
# 연습문제 1-9. 아래 코드를 수정하세요.
student_Age = 30
print(student_Age)
# Out:
# 30

# %%
### 문제 1-10) (도전) 총 지출 변수 만들기
Total_cost = 10000
print(Total_cost)
# Out:
# 10000

# %%
# 연습문제 2-1
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
# 연습문제 2-2
x=10
x="10"
print(type(x))
# Out:
# <class 'str'>

# %%
# 연습문제 2-3
x=int("100")
print(x+25)
# Out:
# 125

# %%
# 연습문제 2-4
x=float("3.5")
print(x*2)
# Out:
# 7.0

# %%
# 연습문제 2-5
n=7
x= str(n)
print(type(x))
# Out:
# <class 'str'>

# %%
# 연습문제 2-6. 아래 코드를 수정하세요.
# result = "10"+20
# 해결법
result = int("10")+20
print(result)
# Out:
# 30

# %%
# 연습문제 2-7
result = 10 / 2
print(result,type(result))
# Out:
# 5.0 <class 'float'>

# %%
# 연습문제 2-8
print("1" * 5)
# Out:
# 11111

# %%
# 연습문제 2-9
print(int(3.99))
# int는 값을 정수로 변환해주기 때문이다.
# Out:
# 3

# %%
# 문제 2-10
print(int(input().replace(",",""))+10)
# Out:
# 1244

# %%
# 연습문제 3-1. 아래 코드를 완성하세요.
a = 8
b = 3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 11
# 5
# 24
# 2.6666666666666665

# %%
# 연습문제 3-2
print((10-2)*3)
# Out:
# 24

# %%
# 연습문제 3-3
print("hi"*4)
# Out:
# hihihihi

# %%
# 연습문제 3-4
a,b= 5,9
print(a,b)
# Out:
# 5 9

# %%
# 연습문제 3-5
a = 100
b = 200
a,b = b,a
print(a,b)
# Out:
# 200 100

# %%
# 연습문제 3-6 아래 코드를 완성하세요
x=y=z=1
y=10

print(x, y, z)
# Out:
# 1 10 1

# %%
# 연습문제 3-7
x=input()
a,b= x.split()
a=int(a)
b= int(b)
print(a*b)
# Out:
# 24

# %%
# 연습문제 3-8
a, b = input("두 값을 입력하세요: ").split()
print(type(a),type(b))
# Out:
# <class 'str'> <class 'str'>

# %%
# 연습문제 3-9
# /연산자는 항상 float형을 반환하기 때문이다.

# %%
# 연습문제 3-10
result = 10 / 3
print(f"{result:.2f}")
# Out:
# 3.33
