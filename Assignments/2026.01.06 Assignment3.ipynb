# %%
# 불변 문제 1
word = "python"
print(word[0].upper()+word[1:])
# Out:
# Python

# %%
# 불변 문제 2
text = "hello"
text_change=text.replace("l","L",2)
print(text_change)
# Out:
# heLLo

# %%
# 불변 문제 3
msg = "good"
print(msg+"!")
# Out:
# good!

# %%
# 불변 문제 4
text = "  ABC  "
text_strip=text.strip()
print(text_strip.lower())
# Out:
# abc

# %%
# 불변 문제 5
# 이유: 변경한 이후 text라는 변수에 다시 대입을 하지 않았기 때문에 text는 불변한다.

# %%
# 불변 문제 6
s = "abc"
print(s[1])
# Out:
# b

# %%
# 불변 문제 7
# 설명: 문자열의 일부는 변경이 불가능하며,새 문자열을 만들어야한다.

# %%
# 불변 문제 8
fruit = "banana"
print(fruit[0].upper() + fruit[1:])
# Out:
# Banana

# %%
# 슬라이싱 문제 1
s = "Python"
print(s[0],s[-1])
# Out:
# P n

# %%
# 슬라이싱 문제 2
s = "abcdef"
print(s[1:4])
# Out:
# bcd

# %%
# 슬라이싱 문제 3
s = "abcdef"
print(s[-3:])
# Out:
# def

# %%
# 슬라이싱 문제 4
s = "0123456789"
print(s[1::2])
# Out:
# 13579

# %%
# 슬라이싱 문제 5
s = "0123456789"
print(s[0::2])
# Out:
# 02468

# %%
# 슬라이싱 문제 7
s = "Python"
print(f"'{s[0:0]}'")
# 설명: 시작과 끝 인덱스가 같으면 빈 문자열이 반환됩니다.
# Out:
# ''

# %%
# 슬라이싱 문제 8
s = "Python"
print(s[-1],s[-1:])
# Out:
# n n

# %%
# 슬라이싱 문제 9
s = "Hello, World!"
print(s[7:12])
# Out:
# World

# %%
# 슬라이싱 문제 10
email = "abc@gmail.com"
print(email[4:9])
# Out:
# gmail

# %%
# 메서드/find/index 문제 1
text = "   Hello   "
print(text.strip())
# Out:
# Hello

# %%
# 메서드/find/index 문제 2
text = "A,B,C"
split_text = text.split()
result = "-".join(split_text)
print(result)
# Out:
# A,B,C

# %%
# 메서드/find/index 문제 3
text = "banana"
print(text.count("na"))
# Out:
# 2

# %%
# 메서드/find/index 문제 7
text = "ha ha ha"
print(text.replace("ha","ho"))
# Out:
# ho ho ho

# %%
# 메서드/find/index 문제 9
data = "name: 적토마"
idx = int(data.find(":"))
name = data[idx+1:].strip()
print(name)
# Out:
# 적토마

# %%
# 메서드/find/index 문제 10
date_str = "2026/01/04"
year, month, day = date_str.split("/")
print(f"연도: {year}, 월: {month}, 일: {day}")
# Out:
# 연도: 2026, 월: 01, 일: 04
