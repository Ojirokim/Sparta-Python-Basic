# %%
# 종합 문제 1

# %% [markdown]
# x에 현재보다 1더 큰 값을 대입하라.

# %%
# 종합 문제 2

# %% [markdown]
# 타입이 str이기 때문이다. int()로 변형해주면 된다.

# %%
# 종합 문제 3

# %% [markdown]
# 두 변수의 값을 서로 바꿔서 저장해 준다.

# %%
# 종합 문제 4

# %% [markdown]
# x,y,z 전부 같은 값을 저장하기 위해서

# %%
# 종합 문제 5

# %% [markdown]
# /연산자는 항상 float 타입을 반환하기 때문이다.

# %%
# 종합 문제 6

# %% [markdown]
# 변수는 대문자 소문자를 구분하기 때문이다.

# %%
# 종합 문제 7

# %% [markdown]
# 변수명에는 띄어쓰기를 하면 안되기 때문이다.

# %%
# 종합 문제 8

# %% [markdown]
# Function 안에 있는 전역 변수는 읽기는 default로 가능하다. 하지만, 수정하는 것은 global keyword로 정의하고 변경해야지만 가능하다.

# %%
# 종합 문제 9

# %% [markdown]
# 전자는 str의 합으로 그냥 이어진다. 후자는 숫자의 합으로 계산이 이루어진다.

# %%
# 종합 문제 10
x=input("띄어쓰기를 사용하여 두 숫자를 입력하세요: ")
a, b= map(int,x.split())
print(f"{a+b}/{a-b}/{a*b}/{a/b}")
# Out:
# 33/27/90/10.0
