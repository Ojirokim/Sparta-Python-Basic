# %% [markdown]
# 클래스 정의하기

# %%
class Person:
    def __init__(self, name, age): # 생성자
        self.name = name  # 인스턴스 변수
        self.age = age # 인스턴스 변수

    def introduce(self):
        print(f"안녕하세요, 제 이름은 {self.name}이고, 나이는 {self.age}살입니다.")

# %% [markdown]
# ### 실습
# Person 클래스 안에 인스턴스 자기자신의 변수를 만드세요.
# 그리고 mbti를 출력하는 함수 def call을 만드세요.
# 아래 사람들을 찍어내세요.

# %%
class Person:
    def __init__(self,name, age, mbti):
        self.name = name
        self.age = age
        self.mbti = mbti
    def call(self):
        return self.name, self.age, self.mbti
    def call_mbti(self):
        return f"제 mbti는 : {self.mbti}입니다."

hodong = Person('강호동',5,'ESTP')
jonny = Person('쟈니',32,'ENTP')
redhorse = Person('적토마',65,'INFJ')
print(hodong.call())
print(hodong.call_mbti())
# Out:
# ('강호동', 5, 'ESTP')
# 제 mbti는 : ESTP입니다.

# %% [markdown]
# ## **클래스 변수(class variable)**
# 클래스로부터 만들어진 모든 인스턴스가 공유하는 변수.
# 클래스 블록 내에서 self 없이 바로 변수를 정의하면 클래스 변수로 설정됩니다.

# %%
class Car:
    wheels = 4  # 클래스 변수: 모든 Car 인스턴스는 바퀴가 4개
    def __init__(self, color):
        self.color = color  # 인스턴스 변수: 각 차마다 색이 다를 수 있음

car1 = Car("red")
car2 = Car("blue")

print(car1.color)  # "red" (car1만의 인스턴스 변수)
print(car2.color)  # "blue" (car2만의 인스턴스 변수)

print(car1.wheels) # 4 (클래스 변수는 모든 객체가 공유)
print(car2.wheels) # 4
# Out:
# red
# blue
# 4
# 4

# %% [markdown]
# ### 실습
# Car에 클래스변수 'window'=True 를 저장하세요.
# Car에 인스턴스변수 'name'을 저장하세요.
# 그리고 car1, car2에서 'window'변수값을 출력하세요.
# 그리고 car1, car2에서 'name'변수값을 출력하세요.

# %%
class Car:
    window = True
    def __init__(self,name):
        self.name = name
car1 =Car("red")
car2 =Car("blue")

print(car1.name)
print(car1.name)
print(car1.window)
print(car2.window)
# Out:
# red
# red
# True
# True

# %% [markdown]
# ## 미니실습 1
#
# 아래 코드가 실행되면 무엇이 출력될지 적어보세요.
#
# ```python
# class Dog:
#     species = "dog"
#
#     def __init__(self, name):
#         self.name = name
#
# dog1 = Dog("초코")
# dog2 = Dog("콩이")
#
# print(dog1.name)
# print(dog2.name)
# print(dog1.species)
# print(dog2.species)
# ```

# %%
class Dog:
    species = "dog"

    def __init__(self, name):
        self.name = name

dog1 = Dog("초코")
dog2 = Dog("콩이")

print(dog1.name)
print(dog2.name)
print(dog1.species)
print(dog2.species)
# Out:
# 초코
# 콩이
# dog
# dog

# %% [markdown]
# ## 미니실습 2
#
# 아래 코드에서 잘못된 줄 1개를 찾고, 왜 틀렸는지 설명해 보세요.
# ```python
# class Student:
#     school = "중학교"
#
#     def __init__(self, name):
#         name = name
#
# s1 = Student("민수")
# print(s1.name)
# ```

# %%
class Student:
    school = "중학교"

    def __init__(self, name):
        self.name = name

s1 = Student("민수")
print(s1.name)
# Out:
# 민수

# %% [markdown]
# 클래스 init에서 self.name을 이용해야지만 저장이 된다.

# %% [markdown]
# ## 접근 지정자와 캡슐화
# ```
# class BankAccount:
#     def __init__(self, owner, balance):
#         self.owner = owner
#         self.__balance = balance  # 이 변수는 직접 접근하기 어렵게 함.
#
#     def deposit(self, amount):
#         self.__balance += amount
#
#     def withdraw(self, amount):
#         if self.__balance >= amount:
#             self.__balance -= amount
#         else:
#             print("잔고 부족")
#
#     def get_balance(self):
#         return self.__balance
#
# acc = BankAccount("Alice", 1000)
# print(acc.get_balance())  # 1000
# acc.deposit(500)
# print(acc.get_balance())  # 1500
# acc.withdraw(2000)        # "잔고 부족"
# print(acc.get_balance())  # 1500
#
# # acc.__balance 는 직접 접근 불가능 (AttributeError 발생)
# ```
# 실습타임 : 직접 접근할수없는 또다른 변수 ‘password’를 만들어주세요. 그리고 그 패스워드를 바꿀 수 있는 메서드(change_password)도 만들어주세요.

# %%
class BankAccount:
    def __init__(self, owner, balance, password):
        self.owner = owner
        self.__balance = balance  # 이 변수는 직접 접근하기 어렵게 함.
        self.__password = password # 이 변수는 직접 접근하기 어렵게 함

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if self.__balance >= amount:
            self.__balance -= amount
        else:
            print("잔고 부족")

    def get_balance(self):
        return self.__balance

    def get_password(self):
        return self.__password

    def change_password(self, new_password):
        self.__password = new_password
        return self.__password

acc = BankAccount("Alice", 1000, '123456a')
print(acc.get_balance())  # 1000
acc.deposit(500)
print(acc.get_balance())  # 1500
acc.withdraw(2000)        # "잔고 부족"
print(acc.get_balance())  # 1500
acc.change_password('23445a')
print(acc.get_password())
print(acc._BankAccount__balance)
# Out:
# 1000
# 1500
# 잔고 부족
# 1500
# 23445a
# 1500

# %% [markdown]
# ## 상속(Inheritance)
# ```
# class Animal:
#     def __init__(self, name):
#         self.name = name
#
#     def speak(self):
#         print("동물이 소리를 냅니다.")
#
# class Dog(Animal):  # Animal 클래스를 상속
#     def speak(self):
#         print(f"{self.name}가 멍멍 짖습니다.")
#
# dog = Dog("멍멍이")
# dog.speak()  # "멍멍이가 멍멍 짖습니다."
# ```
# 실습타임 : Dog를 상속받는 Chiwawa 클래스를 만들어주세요. 그리고 Chiwawa 클래스의 speak 함수에서는 print(”치와와는 치왈왈하고 웁니다.”) 가 실행될 수 있도록 해주세요.

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print("동물이 소리를 냅니다.")

class Dog(Animal):  # Animal 클래스를 상속
    def speak(self):
        print(f"{self.name}가 멍멍 짖습니다.")

class Chiwawa(Dog):
    def speak(self):
        print(f'치와와는 치왈왈하고 웁니다.')
wawa = Chiwawa("재롱이")
dog = Dog("멍멍이")
wawa.speak()  # "멍멍이가 멍멍 짖습니다."
# Out:
# 치와와는 치왈왈하고 웁니다.

# %% [markdown]
# ## 실제 예제: 학생 관리 시스템
# ```python
# class Student:
#     def __init__(self, name, student_id):
#         self.name = name
#         self.student_id = student_id
#         self.scores = []
#
#     def add_score(self, score):
#         self.scores.append(score)
#
#     def get_average(self):
#         if not self.scores:
#             return 0
#         return sum(self.scores) / len(self.scores)
#
#     def introduce(self):
#         print(f"이름: {self.name}, 학번: {self.student_id}, 평균점수: {self.get_average()}")
#
# # 사용 예시
# s1 = Student("Alice", "20230001")
# s1.add_score(90)
# s1.add_score(85)
# s1.add_score(100)
#
# s2 = Student("Bob", "20230002")
# s2.add_score(70)
# s2.add_score(75)
#
# s1.introduce()  # 이름: Alice, 학번: 20230001, 평균점수: 91.666...
# s2.introduce()  # 이름: Bob, 학번: 20230002, 평균점수: 72.5
# ```

# %%
class BankAccount:
    def __init__(self, owner, balance, password):
        self.owner = owner
        self.__balance = balance
        self.__password = password

    def get_balance(self):
        return self.__balance
class SpecialAccount(BankAccount):
    def __init__(self, owner, balance, password):
        super().__init__(owner, balance, password)
        self.__balance = 0   # <-- creates _SpecialAccount__balance

    def get_special_balance(self):
        return self.__balance
acc = SpecialAccount("Alice", 1000, "secret")
print("BankAccount get_balance():", acc.get_balance())
print("SpecialAccount get_special_balance():", acc.get_special_balance())
# Out:
# BankAccount get_balance(): 1000
# SpecialAccount get_special_balance(): 0

# %% [markdown]
# ## 문제 1 | Point 클래스
# **문제 설명**
#
# - `Point`라는 이름의 클래스를 정의하세요.
# - **인스턴스 변수** `x`, `y`를 만들어 좌표를 저장합니다.
# - 메서드 기능은 아래와 같습니다.
#     1. `move(dx, dy)` → 현재 좌표를 `dx`, `dy`만큼 이동시킴
#     2. `show()` → 현재 좌표를 `"Point(x, y)"` 형식으로 출력
#
# **예시 실행**
#
# ```python
# p = Point(1, 2)
# p.move(2, 3)     # (1+2, 2+3) → (3, 5)
# p.show()         # Point(3, 5)
# ```

# %%
class Point:
    def __init__(self,x ,y):
        self.x = x
        self.y=y
    def move(self, dx, dy):
        self.x+=dx
        self.y+=dy
    def show(self):
        print(f"Point({self.x},{self.y})")
p = Point(1,2)
p.move(2,3)
p.show()
# Out:
# Point(3,5)

# %% [markdown]
# ### 문제 2 | Counter 클래스
#
# **문제 설명**
#
# - `Counter`라는 이름의 클래스를 정의하세요.
# - 클래스 변수 `count`는 생성된 객체의 개수를 기록합니다.
# - 객체가 생성될 때마다 `count`를 1 증가시키세요.
# - 클래스 메서드 `how_many()`를 만들어 현재까지 몇 개의 인스턴스가 만들어졌는지 출력하세요.
#
# **예시 실행**
#
# ```python
# a = Counter()
# b = Counter()
# c = Counter()
# Counter.how_many()   # 현재까지 3개 생성
# ```

# %%
class Counter:
    count=0
    def __init__(self):
        Counter.count +=1
    @classmethod
    def how_many(cls):
        print(f"현재까지 만들어진 인스턴스는 {cls.count}개 입니다.")
a= Counter()
b= Counter()
c= Counter()
Counter.how_many()

# %% [markdown]
# ## 문제 3 | Temperature 클래스
#
# **문제 설명**
#
# - `Temperature`라는 이름의 클래스를 정의하세요.
# - 인스턴스 변수 `celsius`에 섭씨 온도를 저장합니다.
# - 메서드 기능은 아래와 같습니다.
#     1. `to_fahrenheit()` → 섭씨를 화씨로 변환하여 반환 (`℉ = ℃ × 9/5 + 32`)
#     2. `is_boiling()` → 섭씨 100도 이상이면 `True`, 아니면 `False` 반환
#
# **예시 실행**
#
# ```python
# t = Temperature(36.5)
# print(t.to_fahrenheit())  # 97.7
# print(t.is_boiling())     # False
#
# t2 = Temperature(120)
# print(t2.is_boiling())    # True
# ```

# %%
class Temperature:
    def __init__(self, celsius):
        self.celsius = celsius
    def to_fahrenheit(self):
        return self.celsius*9/5 +32
    def is_boiling(self):
        if self.celsius>=100:
            return True
        else:
            return False
t = Temperature(36.5)
print(t.to_fahrenheit())  # 97.7
print(t.is_boiling())     # False

t2 = Temperature(120)
print(t2.is_boiling())    # True
# Out:
# 97.7
# False
# True
