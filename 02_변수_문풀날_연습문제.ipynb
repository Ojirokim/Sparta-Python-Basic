# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "id": "39d5c70c",
   "metadata": {},
   "source": [
    "### 🧩 연습문제 1: 변수 이름 (1~10문제)\n",
    "\n",
    "1) 학생 이름을 저장하는 변수명을 `snake_case`로 만들어 보세요.  \n",
    "2) 한 개 가격을 저장하는 변수명을 `snake_case`로 만들어 보세요.  \n",
    "3) 아래 코드의 변수명을 더 읽기 쉽게 바꿔 보세요(의미 있는 이름으로).  \n",
    "4) `Score`와 `score`를 각각 만들고 다른 값을 넣어 출력해 보세요.  \n",
    "5) 문자열 `\"15\"`와 숫자 `15`를 각각 변수에 저장하고 `type()`으로 확인해 보세요.  \n",
    "6) 공백이 들어간 변수명을 만들면 어떤 에러가 나는지 확인해 보세요(주석을 풀어서).  \n",
    "7) 숫자로 시작하는 변수명을 만들면 어떤 에러가 나는지 확인해 보세요(주석을 풀어서).  \n",
    "8) 예약어 `for`를 변수명으로 쓰면 왜 안 되는지 한 줄로 설명해 보세요(코드는 실행하지 않아도 됩니다).  \n",
    "9) `studentAge`를 `snake_case`로 바꿔 변수로 만들어 보세요.  \n",
    "10) (도전) “총 지출”을 의미하는 변수명을 스스로 정하고 만들어 보세요.\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "b93adc5e",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 1-1\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "49f031f4",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 1-2\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "6414f103",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 1-3\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "160c58b3",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 1-4\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "811111a4",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 1-5\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "f72151ef",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 1-6\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "929b55e4",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 1-7\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "618a9062",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 1-8\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "7646cce2",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 1-9\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "79ffe745",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 1-10\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "35ae6e2a",
   "metadata": {},
   "source": [
    "### 🧩 연습문제 2: type/형변환 (1~10문제)\n",
    "\n",
    "1) `x=10` 저장 후 `type(x)` 출력  \n",
    "2) 같은 변수 `x`에 `\"10\"` 저장 후 `type(x)` 출력  \n",
    "3) `\"100\"`을 int로 바꿔 25 더하기  \n",
    "4) `\"3.5\"`를 float로 바꿔 2 곱하기  \n",
    "5) `n=7`일 때 `str(n)`의 타입 확인  \n",
    "6) (헷갈림) `\"10\" + 20`은 왜 에러일까요? 해결해 보세요.  \n",
    "7) `10 / 2`의 타입은 무엇인가요?  \n",
    "8) `\"1\" * 5` 결과를 예측하고 실행해 보기  \n",
    "9) `int(3.99)`는 왜 3일까요? 직접 확인  \n",
    "10) (도전) 사용자 입력 `\"1,234\"`를 콤마 제거 후 int로 바꿔 10 더하기\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "c39af880",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 2-1\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "537feaa7",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 2-2\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "f83eb267",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 2-3\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "f215b91f",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 2-4\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "1a6cbfa6",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 2-5\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "577abeed",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 2-6\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "2d3d4174",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 2-7\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "b27755de",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 2-8\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "cab5faf4",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 2-9\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "8c955acd",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 2-10\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "d0f368be",
   "metadata": {},
   "source": [
    "### 🧩 연습문제 3: 산술/다중할당 (1~10문제)\n",
    "\n",
    "1) `a=8`, `b=3`일 때 `+ - * /` 결과 출력  \n",
    "2) `(10 - 2) * 3` 계산 출력  \n",
    "3) `\"hi\" * 4` 출력  \n",
    "4) `a, b = 5, 9` 만들고 출력  \n",
    "5) `a=100`, `b=200` swap하여 출력  \n",
    "6) `x=y=z=1` 후 `y`만 10으로 바꾸고 출력  \n",
    "7) 사용자에게 정수 2개 입력받아 곱 출력(공백 구분)  \n",
    "8) (헷갈림) `a, b = input().split()`은 숫자인가요? `type()` 확인  \n",
    "9) (헷갈림) `10 / 2`가 `5.0`이 되는 이유를 한 줄로 설명(주석에)  \n",
    "10) (도전) 나눗셈 결과를 소수 둘째 자리까지 f-string으로 출력\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "65a3052d",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 3-1\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "5875f22a",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 3-2\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "2412323d",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 3-3\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "2f102568",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 3-4\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "0f0e614f",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 3-5\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "2760deb5",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 3-6\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "8f9e6df9",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 3-7\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "e928e5e1",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 3-8\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "5dd91dcc",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 3-9\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "19033f85",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 3-10\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "265d37f1",
   "metadata": {},
   "source": [
    "### 🧩 연습문제 4: 스코프(1~10문제)\n",
    "\n",
    "1) 전역 변수 `x=5`를 만들고 함수 안에서 읽어 출력하세요.  \n",
    "2) 함수 안에서 `x=10`으로 새로 만들고, 함수 밖 x가 바뀌는지 확인하세요.  \n",
    "3) (추천 방식) return으로 1 증가시키는 함수를 만들고 전역 변수에 다시 저장하세요.  \n",
    "4) global을 사용해서 전역 변수 값을 1 증가시키세요.  \n",
    "5) 함수 안에서 만든 `y`를 함수 밖에서 출력하면 어떤 에러인지 확인하세요(주석 풀기).  \n",
    "6) 전역 변수 이름과 지역 변수 이름이 같아도 되는지 예제로 확인하세요.  \n",
    "7) (헷갈림) 함수 안에서 `print(x)`는 되는데 `x = x + 1`은 왜 위험한지 한 줄로 설명하세요.  \n",
    "8) (도전) 카운터를 0에서 시작해 함수를 3번 호출할 때마다 1씩 늘려 출력하세요.  \n",
    "9) (도전) 용돈에서 지출을 빼는 함수를 return 방식으로 적용해 보세요.  \n",
    "10) (도전) 입력을 3번 받아 전역 변수에 누적합을 저장해 보세요.\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "3513e63f",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 4-1\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "83c1fd16",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 4-2\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "51695feb",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 4-3\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "8890d758",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 4-4\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "6bab13c8",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 4-5\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "63a26074",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 4-6\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "0d0a0284",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 4-7\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "b9210454",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 4-8\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "77518210",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 4-9\n",
    "# TODO\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "8c2e426c",
   "metadata": {},
   "outputs": [],
   "source": [
    "# 연습문제 4-10\n",
    "# TODO\n"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
