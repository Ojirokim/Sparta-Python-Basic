# %% [markdown]
# ### 🧩 연습문제: 불변(immutable) (총 8문제)
#
# 1) `word="python"`에서 첫 글자만 대문자로 바꿔서 `Python`을 만들어 출력하세요(슬라이싱 사용).
# 2) `"hello"`에서 `l`을 모두 `L`로 바꿔 출력하세요(`replace`).
# 3) 문자열 `msg="good"`에 `"!"`를 붙여 출력하세요.
# 4) `"  ABC  "`에서 양쪽 공백을 제거하고 소문자로 바꿔 출력하세요(`strip`, `lower`).
# 5) (헷갈림) `text.replace("a","b")`를 했는데 왜 text가 안 바뀌는지 설명해 보세요.
# 6) `s="abc"`일 때 `s[1]`은 무엇인가요? 출력해 보세요.
# 7) (헷갈림) 문자열을 수정하려고 `s[0]="X"`를 하면 왜 에러가 나나요? 한 줄로 설명해 보세요.
# 8) (도전) `"banana"`에서 첫 글자 `b`만 `B`로 바꿔 출력하세요(모두가 아니라 첫 글자만).

# %%
# 불변 문제 1
# TODO

# %%
# 불변 문제 2
# TODO

# %%
# 불변 문제 3
# TODO

# %%
# 불변 문제 4
# TODO

# %%
# 불변 문제 5
# TODO

# %%
# 불변 문제 6
# TODO

# %%
# 불변 문제 7
# TODO

# %%
# 불변 문제 8
# TODO

# %% [markdown]
# ### 🧩 연습문제: 인덱싱/슬라이싱 (총 10문제)
#
# 1) `s="Python"`에서 첫 글자와 마지막 글자를 출력하세요.
# 2) `s="abcdef"`에서 `"bcd"`를 슬라이싱으로 추출하세요.
# 3) `s="abcdef"`에서 뒤에서 3글자를 추출하세요.
# 4) `s="0123456789"`에서 `13579`만 추출하세요(슬라이싱 step 사용).
# 5) `s="0123456789"`에서 `02468`만 추출하세요.
# 6) `s="racecar"`를 뒤집어서 같은지 비교해 “회문인지” 확인해 보세요(힌트: `[::-1]`).
# 7) (헷갈림) `s[0:0]`의 결과는 무엇인가요? 실행해 보고 설명해 보세요.
# 8) (헷갈림) `s[-1:]`과 `s[-1]`은 무엇이 다른가요?
# 9) `s="Hello, World!"`에서 `World`만 추출하세요.
# 10) (도전) 이메일 `"abc@gmail.com"`에서 `"gmail"`만 추출하세요(점과 @ 활용).

# %%
# 슬라이싱 문제 1
# TODO

# %%
# 슬라이싱 문제 2
# TODO

# %%
# 슬라이싱 문제 3
# TODO

# %%
# 슬라이싱 문제 4
# TODO

# %%
# 슬라이싱 문제 5
# TODO

# %%
# 슬라이싱 문제 6
# TODO

# %%
# 슬라이싱 문제 7
# TODO

# %%
# 슬라이싱 문제 8
# TODO

# %%
# 슬라이싱 문제 9
# TODO

# %%
# 슬라이싱 문제 10
# TODO

# %% [markdown]
# ### 🧩 연습문제: 전처리 메서드 & find/index (총 10문제)
#
# 1) `"   Hello   "`에서 양쪽 공백 제거 후 `"hello"`로 만들어 출력하세요.
# 2) `"A,B,C"`를 `split(",")`으로 나눈 뒤, `"-"`로 다시 join해서 `"A-B-C"`를 만드세요.
# 3) `"banana"`에서 `"na"`가 몇 번 나오는지 출력하세요.
# 4) `"abc@gmail.com"`에서 `@` 위치를 찾아 아이디와 도메인을 분리해 출력하세요.
# 5) (헷갈림) `find` 결과가 0일 수 있다는 것을 예시로 확인하고, 올바른 조건문을 작성하세요.
# 6) `"10, 20, 30"`에서 공백을 정리한 뒤 정수 리스트로 바꿔 합을 출력하세요(이전 시간과 연결).
# 7) `"ha ha ha"`에서 `"ha"`를 `"ho"`로 바꿔 출력하세요.
# 8) `"Hello Python"`에서 `"Java"`가 없을 때, `find()`와 `index()`가 어떻게 다른지 코드로 확인하세요(try/except).
# 9) (도전) `"name: 적토마"`에서 `:` 뒤의 값만 공백 제거해서 추출하세요.
# 10) (도전) `"2026/01/04"`를 split해서 `2026`, `01`, `04`를 각각 변수에 담아 출력하세요.

# %%
# 메서드/find/index 문제 1
# TODO

# %%
# 메서드/find/index 문제 2
# TODO

# %%
# 메서드/find/index 문제 3
# TODO

# %%
# 메서드/find/index 문제 4
# TODO

# %%
# 메서드/find/index 문제 5
# TODO

# %%
# 메서드/find/index 문제 6
# TODO

# %%
# 메서드/find/index 문제 7
# TODO

# %%
# 메서드/find/index 문제 8
# TODO

# %%
# 메서드/find/index 문제 9
# TODO

# %%
# 메서드/find/index 문제 10
# TODO

# %% [markdown]
# ### 🧩 연습문제: Raw 문자열 (총 7문제)
#
# 1) `"\n"`을 출력하면 어떤 일이 일어나나요? 직접 확인하세요.
# 2) `"C:\new\test"`를 그대로 출력하면 어떤 문제가 생기나요?
# 3) 위 문제를 Raw 문자열로 고쳐 안전하게 출력하세요.
# 4) `"A\tB"`는 어떻게 출력되나요?
# 5) `r"A\tB"`는 어떻게 출력되나요?
# 6) `repr()`을 사용해서 일반 문자열과 raw 문자열의 차이를 확인해 보세요.
# 7) (도전) 아래 두 패턴이 같은 의미인지 확인해 보세요: `"\\d+"` 와 `r"\d+"`

# %%
# Raw 문자열 문제 1
# TODO

# %%
# Raw 문자열 문제 2
# TODO

# %%
# Raw 문자열 문제 3
# TODO

# %%
# Raw 문자열 문제 4
# TODO

# %%
# Raw 문자열 문제 5
# TODO

# %%
# Raw 문자열 문제 6
# TODO

# %%
# Raw 문자열 문제 7
# TODO
